# %% [markdown]
# <a href="https://colab.research.google.com/github/gizattos/Python/blob/master/DriveDownloadDataBaseCeptis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## bibliotecas 
import pandas as pd
import warnings
import sklearn
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from os import path
from PIL import Image
import os
# import squarify  
# from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
warnings.filterwarnings('ignore')
##pd.set_option('display.max_rows', 100)

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
def procura_drive(diretorio):
  file_path_xls=""
  output = [dI for dI in os.listdir(diretorio) if os.path.isdir(os.path.join(diretorio,dI))]
  for pasta in output :
    file_path = diretorio +"/"+pasta
    lst = os.listdir(file_path)
    matching = [s for s in lst if '.xls' in s]
    for file in matching:
      file_path_xls += file_path+"/"+file+","
  file_path_xls_list = file_path_xls.split(sep=",")
  return file_path_xls_list

# %%
arquivos = procura_drive("/content/drive/Shared drives/Confirma/Ceptis/5. Dados Brutos/2019")

# %%
arquivos[0]
# Out:
# '/content/drive/Shared drives/Confirma/Ceptis/5. Dados Brutos/2019/12_Dezembro/RelatorioDePublicacoes-_01_Dez_2019a31_Dez_2019.xlsx'

# %%
arquivos
# Out:
# ['/content/drive/Shared drives/Confirma/Ceptis/5. Dados Brutos/2019/04_Abril/Ceptis-RelatorioDePublicacoes-_01_Abr_2019a30_Abr_2019.xlsx',
#  '/content/drive/Shared drives/Confirma/Ceptis/5. Dados Brutos/2019/02-03_Fevereiro a Março/Ceptis-RelatorioDePublicacoes-_28_Fev_2019a31_Mar_2019.xlsx',
#  '/content/drive/Shared drives/Confirma/Ceptis/5. Dados Brutos/2019/05_Maio/RelatorioDePublicacoes-_01_Mai_2019a31_Mai_2019.xlsx',
#  '/content/drive/Shared drives/Confirma/Ceptis/5. Dados Brutos/2019/06_Junho/RelatorioDePublicacoes-_01_Jun_2019a30_Jun_2019.xlsx',
#  '/content/drive/Shared drives/Confirma/Ceptis/5. Dados Brutos/2019/07_Julho/RelatorioDePublicacoes-_01_Jul_2019a31_Jul_2019.xlsx',
#  '/content/drive/Shared drives/Confirma/Ceptis/5. Dados Brutos/2019/08_Agosto/RelatorioDePublicacoes-_01_Ago_2019a31_Ago_2019.xlsx',
#  '/content/drive/Shared drives/Confirma/Ceptis/5. Dados Brutos/2019/09_Setembro/RelatorioDePublicacoes-_01_Set_2019a30_Set_2019.xlsx',
# ...

# %%
df1 = pd.read_excel(arquivos[0])
df2 = pd.read_excel(arquivos[1])
df3 = pd.read_excel(arquivos[2])
df4 = pd.read_excel(arquivos[3])
df5 = pd.read_excel(arquivos[4])
df6 = pd.read_excel(arquivos[5])
df7 = pd.read_excel(arquivos[6])
df8 = pd.read_excel(arquivos[7])
df9 = pd.read_excel(arquivos[8])
df10 = pd.read_excel(arquivos[9])

# %%
df_unico = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10], axis=0, ignore_index=True)

# %%
df_unico.head()
# Out:
#    Ordem                    Canal  ... Outras Reações Total de Reações
# 0      1                  YouTube  ...            NaN              NaN
# 1      2                  Twitter  ...            NaN              NaN
# 2      3  Comentários no Facebook  ...            NaN              NaN
# 3      4                    Blogs  ...            NaN              NaN
# 4      5                  Portais  ...            NaN              NaN
#
# [5 rows x 31 columns]

# %%
df_unico
# Out:
#         Ordem                    Canal  ... Outras Reações Total de Reações
# 0           1                  YouTube  ...            NaN              NaN
# 1           2                  Twitter  ...            NaN              NaN
# 2           3  Comentários no Facebook  ...            NaN              NaN
# 3           4                    Blogs  ...            NaN              NaN
# 4           5                  Portais  ...            NaN              NaN
# ...       ...                      ...  ...            ...              ...
# 217072  27115                  Portais  ...            0.0              NaN
# 217073  27116                  Portais  ...            0.0              NaN
# 217074  27117                  Portais  ...            0.0              NaN
# 217075  27118                  Portais  ...            0.0              NaN
# 217076  27119                  Portais  ...            0.0              NaN
#
# [217077 rows x 31 columns]

# %%
df_unico.to_excel("ceptis_2019.xlsx")
